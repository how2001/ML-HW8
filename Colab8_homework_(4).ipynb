# %% [markdown]
# # CycleGAN Homework: Van Gogh ↔ Photo Style Transfer (HW8)
#
# Welcome to the 8th homework!
#
# - Code cells that have `TODO` or `raise NotImplementedError` comments are left blank for you.
# - Insert additional experiment cells whenever you need to debug, visualize, or keep notes.
# - Keep this notebook clean and readable.

# %% [markdown]
# ## Homework Baseline & Evaluation Criteria
#
# **Baseline configuration**
# - Dataset: `vangogh2photo` from the original CycleGAN release.
# - Generators/ Discriminators
# - Training
# - Logging: save checkpoints in the training process.
#
# **Evaluation criteria**
# - `Pass / Baseline`: Model trains well, losses trend downward, and validation grids show recognizable Van Gogh ↔ photo translation.
# - `Strong`: All baseline requirements + clear hyperparameter discussion, clean checkpoints, and at least one successful custom-image translation.
# - `Excellent`: Includes ablations/experiments.

# %% [markdown]
# ### Core Imports & Utilities

# %%
# Base imports and helpers (feel free to extend, but keep everything centralized here).
import os, sys, time, math, random, zipfile, urllib.request, shutil
from dataclasses import dataclass
from pathlib import Path

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,Dataset
from torchvision import transforms, datasets, utils as vutils
import torch.nn.init as init
from PIL import Image
from tqdm import tqdm
from torchvision.utils import save_image
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)

def set_seed(seed: int = 2025):
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(2025)
# Out:
# Device: cuda

# %% [markdown]
# ## 1. Configuration
#
# Define a `Config` dataclass (or a simple namespace) that stores paths, hyperparameters, and logging cadence. You are free to tweak values, but document any deviation from the baseline in your report.
#
# **Checklist**
# - [ ] Fill in every field (project name, directories, batch size, epochs, learning rate, lambda terms, sampling cadence).
# - [ ] Create the necessary directories (`data`, `outputs/train`, `outputs/val`, `outputs/test`, `checkpoints`, etc.).
# - [ ] Print `cfg` so that future cells can reference it and so graders can quickly see your settings.

# %%
from dataclasses import dataclass
@dataclass
class Config:
    project: str = "cyclegan_vangogh2photo_hw"
    data_root: str = "./data"
    dataset_name: str = "vangogh2photo"
    outputs: str = "./outputs"
    checkpoints: str = "./checkpoints"#data_root (資料集), outputs (輸出), checkpoints (模型儲存)
    img_size: int = 256
    batch_size: int = 1
    num_workers: int = 4
    epochs: int = 30
    lr: float = 2e-4
    beta1: float = 0.5
    beta2: float = 0.999
    decay_start_epoch = 100
    lambda_cyc: float = 10.0
    lambda_idt: float = 5.0
    sample_every: int = 10
    save_every_epochs: int = 50
    val_fixed_n: int = 4

cfg = Config()

Path(cfg.data_root).mkdir(parents=True, exist_ok=True)
Path(cfg.outputs).mkdir(parents=True, exist_ok=True)
Path(cfg.checkpoints).mkdir(parents=True, exist_ok=True)
Path(f"{cfg.outputs}/train").mkdir(parents=True, exist_ok=True)
Path(f"{cfg.outputs}/val").mkdir(parents=True, exist_ok=True)
Path(f"{cfg.outputs}/test").mkdir(parents=True, exist_ok=True)

cfg
# Out:
# Config(project='cyclegan_vangogh2photo_hw', data_root='./data', dataset_name='vangogh2photo', outputs='./outputs', checkpoints='./checkpoints', img_size=256, batch_size=1, num_workers=4, epochs=30, lr=0.0002, beta1=0.5, beta2=0.999, lambda_cyc=10.0, lambda_idt=5.0, sample_every=10, save_every_epochs=50, val_fixed_n=4)

# %% [markdown]
# ## 2. Dataset Download (VanGogh ↔ Photo)
#
# Download the official CycleGAN dataset, cache the zip, and extract it into `cfg.data_root`.

# %%
from pathlib import Path
import urllib.request
import zipfile

def download_and_extract_cyclegan_dataset(name: str, data_root: str):#存到data_root叫name
    data_root = Path(data_root)
    data_root.mkdir(parents=True, exist_ok=True)

    url = f"http://efrosgans.eecs.berkeley.edu/cyclegan/datasets/{name}.zip"
    dest_zip = data_root / f"{name}.zip"#./data/vangogh2photo.zip
    target_dir = data_root / name#./data/vangogh2photo

    if target_dir.exists() and any(target_dir.iterdir()):
        print(f"[OK] Dataset already present at {target_dir}")
        return target_dir

    print(f"[DL] Downloading {url} -> {dest_zip}")
    try:
        urllib.request.urlretrieve(url, dest_zip)
    except Exception as e:
        print("[WARN] Primary URL failed:", e)
        raise

    print("[ZIP] Extracting...")
    with zipfile.ZipFile(dest_zip, 'r') as zf:
        zf.extractall(data_root)

    print("[CLEAN] Removing zip")
    dest_zip.unlink(missing_ok=True)

    return target_dir


data_dir = download_and_extract_cyclegan_dataset(cfg.dataset_name, cfg.data_root)#./data/vangogh2photo
print("Data directory:", data_dir)
print("Subfolders:", list(Path(data_dir).iterdir()))
# Out:
# [OK] Dataset already present at data/vangogh2photo
# Data directory: data/vangogh2photo
# Subfolders: [PosixPath('data/vangogh2photo/trainB'), PosixPath('data/vangogh2photo/testB'), PosixPath('data/vangogh2photo/trainA'), PosixPath('data/vangogh2photo/testA')]

# %% [markdown]
# ## 3. Datasets & Dataloaders
#
# Create PyTorch datasets and dataloaders for each domain. Use  data augmentation (ex: horizontal flips, normalization to [-1, 1]) for training and deterministic transforms for validation/testing.
#
# **Checklist**
# - [ ] Build helper transforms for train/eval.
# - [ ] Instantiate ImageFolder (or a custom dataset) for `trainA`, `trainB`, `testA`, and `testB`.
# - [ ] Create dataloaders with the batch size and worker count from `cfg`.
# - [ ] Cache a few fixed batches (`fixed_A`, `fixed_B`) for periodic sampling.
# - [ ] Visualize at least one batch to ensure the transforms/normalization look correct.

# %%
def make_transforms(size: int):
    """Return the training transform pipeline (resize, flip, ToTensor, Normalize)."""
    return transforms.Compose([
        # 調整大小: 將圖像的短邊縮放到 (286)
        transforms.Resize(int(size * 1.12), transforms.InterpolationMode.BICUBIC),
        # 裁剪回目標大小 (256 x 256)
        transforms.RandomCrop(size),
        # 隨機水平翻轉
        transforms.RandomHorizontalFlip(),
        #轉換為 Tensor
        transforms.ToTensor(),
        #將像素值從 [0, 1] 映射到 [-1, 1]
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])


def make_test_transforms(size: int):
    """Return the validation/test transform pipeline (resize, ToTensor, Normalize)."""
    return transforms.Compose([
        #跟make_transforms一樣
        transforms.Resize(int(size * 1.12), transforms.InterpolationMode.BICUBIC),
        transforms.RandomCrop(size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])

trainA_path = Path(data_dir) / "trainA"#data/vangogh2photo/trainA
trainB_path = Path(data_dir) / "trainB"#data/vangogh2photo/trainB
testA_path  = Path(data_dir) / "testA"#data/vangogh2photo/testA
testB_path  = Path(data_dir) / "testB"#data/vangogh2photo/testB

class reconstructdataset(Dataset):
    def __init__(self,root,transform=None):

      self.transform = transform#哪種transform
      self.image_paths = []#圖片路徑
      #把所有image放到image_paths等getitem呼叫
      for filename in os.listdir(root):
            if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
                self.image_paths.append(os.path.join(root, filename))

    def __len__(self):#回傳總共幾帳照片
      return len(self.image_paths)

    def __getitem__(self,idx):#回傳照片
      image_path = self.image_paths[idx]
      image = Image.open(image_path).convert("RGB")
      if self.transform:
            image = self.transform(image)
      return image, 0

#Dataset trainA
trainA = reconstructdataset(
    root=str(trainA_path),
    transform=make_transforms(cfg.img_size)
)
#Dataset trainB
trainB = reconstructdataset(
    root=str(trainB_path),
    transform=make_transforms(cfg.img_size)
)
#Dataset valA
valA = reconstructdataset(
    root=str(testA_path),
    transform=make_test_transforms(cfg.img_size)
)
#Dataset valB
valB = reconstructdataset(
    root=str(testB_path),
    transform=make_test_transforms(cfg.img_size)
)


#DataLoader 接受一個 Dataset ，然後負責將單個樣本組合成批次（Batching）、打亂（Shuffling）、並使用多進程（num_workers）來加速載入
trainA_loader = DataLoader(
    trainA,
    batch_size=cfg.batch_size,
    shuffle=True,           # 訓練時需要打亂順序
    num_workers=cfg.num_workers,
    drop_last=True          # 確保批次大小一致，避免最後一個不完整的批次影響訓練
)
trainB_loader = DataLoader(
    trainB,
    batch_size=cfg.batch_size,
    shuffle=True,           # 訓練時需要打亂順序
    num_workers=cfg.num_workers,
    drop_last=True          # 確保批次大小一致，避免最後一個不完整的批次影響訓練
)
valA_loader = DataLoader(
    valA,
    batch_size=cfg.batch_size,
    shuffle=True,           # 訓練時需要打亂順序
    num_workers=cfg.num_workers,
    drop_last=True          # 確保批次大小一致，避免最後一個不完整的批次影響訓練
)
valB_loader = DataLoader(
    valB,
    batch_size=cfg.batch_size,
    shuffle=True,           # 訓練時需要打亂順序
    num_workers=cfg.num_workers,
    drop_last=True          # 確保批次大小一致，避免最後一個不完整的批次影響訓練
)
# TODO: grab fixed batches for visualization/logging
# fixed_A = next(iter(valA_loader))[0][:cfg.val_fixed_n].to(device)
# fixed_B = next(iter(valB_loader))[0][:cfg.val_fixed_n].to(device)
fixed_A = next(iter(valA_loader))[0][:cfg.val_fixed_n].to(device)#從 val_loader 抓第一個 batch,取出圖片,擷取前 cfg.val_fixed_n 張放到 GPU
fixed_B = next(iter(valB_loader))[0][:cfg.val_fixed_n].to(device)


display_count = min(6, cfg.batch_size) # 顯示最多 6 張圖像

plt.figure(figsize=(12, 8))
plt.suptitle("Train A Loader Sample ", fontsize=16)
#展示圖像
for i in range(display_count):
    plt.subplot(1, 2, i + 1)
    sample_A, _ = next(iter(trainA_loader))
    #獲取單張圖像張量
    single_image_tensor = sample_A[i]

    #將數值範圍從 [-1, 1] 轉回 [0, 1]
    denorm_image = (single_image_tensor * 0.5 + 0.5).clamp(0, 1)

    #維度調整：PyTorch 格式 (C, H, W) -> Matplotlib 格式 (H, W, C)
    # 使用 .permute(1, 2, 0)
    image_np = denorm_image.cpu().permute(1, 2, 0).numpy()

    #繪製圖像
    plt.imshow(image_np))
    plt.title(f"Sample {i+1} (Size: {image_np.shape[0]}x{image_np.shape[1]})")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Fixed batch A shape: torch.Size([1, 3, 256, 256])
# Fixed batch B shape: torch.Size([1, 3, 256, 256])
# Fixed batches for validation logging successfully grabbed and moved to device.
# Transforms/Normalization check complete. Images should be colored and correctly cropped/sized.

# %% [markdown]
# ## 4. Models ( Generator & Discriminator)
#
# Implement the CycleGAN architectures described in class:
#
# - **Generators**
# - **Discriminators**
#
# Document any deviations (e.g., fewer residual blocks) in your report.

# %%
import torchvision.models as models
class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super(ResidualBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim)

    def build_conv_block(self, dim):#ResNet的一個ResidualBlock
        conv_block = []

        conv_block += [nn.ReflectionPad2d(1)]
        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=0, bias=True)]
        conv_block += [nn.InstanceNorm2d(dim)]
        conv_block += [nn.ReLU(True)]

        conv_block += [nn.ReflectionPad2d(1)]
        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=0, bias=True)]
        conv_block += [nn.InstanceNorm2d(dim)]

        return nn.Sequential(*conv_block)#*為了unpack

    def forward(self, x):
        return x + self.conv_block(x)



class ResnetGenerator(nn.Module):
    def __init__(self, input_nc: int = 3, output_nc: int = 3, n_blocks: int = 6, ngf: int = 64):#6個Residual block
        super().__init__()
        model=[]
        model+=[
            nn.ReflectionPad2d(3),
            nn.Conv2d(input_nc, ngf, kernel_size=7, padding=0,bias=True),
            nn.InstanceNorm2d(ngf),
            nn.ReLU(True),
        ]
        n_downsampling = 2
        for i in range(n_downsampling):#先找原本的圖片的特徵
            mult = 2 ** i
            model += [nn.Conv2d(ngf * mult, ngf * mult * 2, kernel_size=3, stride=2, padding=1, bias=True),#(128,128*128),(256,64*64)
                  nn.InstanceNorm2d(ngf * mult * 2),#(128channel norm),(256channel norm)
                  nn.ReLU(True)]

        for i in range(n_blocks):#加入6個block
            model += [ResidualBlock(256)]


        # 執行兩次上採樣：64x64 -> 128x128 -> 256x256
        for i in range(n_downsampling):
            mult = 2 ** (2 - i)
            model += [
                nn.ConvTranspose2d(ngf * mult, int(ngf * mult / 2),
                                   kernel_size=3, stride=2, padding=1,
                                   output_padding=1, bias=True),
                nn.InstanceNorm2d(int(ngf * mult / 2)),
                nn.ReLU(True)
            ]
        model += [nn.ReflectionPad2d(3)]
        model += [nn.Conv2d(ngf, output_nc, kernel_size=7, padding=0)]

        # Tanh 函數將輸出範圍映射到 [-1, 1]
        model += [nn.Tanh()]

        # 將所有層組合為一個 Sequential 模型
        self.model = nn.Sequential(*model)
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # TODO: apply the generator modules
        return self.model(x)


class PatchDiscriminator(nn.Module):
    def __init__(self, input_nc: int = 3, ndf: int = 64, n_layers: int = 3):
        super().__init__()
        model = []
        # 尺寸減半: 256x256 -> 128x128
        model += [
            nn.Conv2d(input_nc, ndf, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, True) # CycleGAN 判別器使用 LeakyReLU
        ]
        # Downsampling三次
        mult_prev = 1
        for i in range(1, n_layers):
            mult = 2 ** i # 當前的channel數 (2, 4, 8, ...)
            model += [
                nn.Conv2d(ndf * mult_prev, ndf * mult, kernel_size=4, stride=2, padding=1, bias=True),
                nn.InstanceNorm2d(ndf * mult),
                nn.LeakyReLU(0.2, True)
            ]
            mult_prev = mult

        # 尺寸不變channel數也不便
        mult = 2 ** n_layers
        model += [
            nn.Conv2d(ndf * mult_prev, ndf * mult, kernel_size=4, stride=1, padding=1, bias=True),
            nn.InstanceNorm2d(ndf * mult),
            nn.LeakyReLU(0.2, True)
        ]
-
        # 尺寸不變但輸出0或1
        model += [
            nn.Conv2d(ndf * mult, 1, kernel_size=4, stride=1, padding=1)
        ]

        self.model = nn.Sequential(*model)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.model(x)

#官方建議的初始化權重
#https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
def init_weights(module: nn.Module):
    classname = module.__class__.__name__

    # 卷積層 (Conv) 和線性層 (Linear)
    if hasattr(module, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        # 初始化權重為 N(0, 0.02)
        init.normal_(module.weight.data, 0.0, 0.02)
        # 如果有 bias 參數，初始化為 0
        if hasattr(module, 'bias') and module.bias is not None:
            init.constant_(module.bias.data, 0.0)

    # Batch Normalization / Instance Normalization 層
    elif classname.find('BatchNorm2d') != -1 or classname.find('InstanceNorm2d') != -1:
        # 權重 (gamma) 初始化為 N(1.0, 0.02)
        if hasattr(module, 'weight') and module.weight is not None:
            init.normal_(module.weight.data, 1.0, 0.02)
        # bias (beta) 初始化為 0
        if hasattr(module, 'bias') and module.bias is not None:
            init.constant_(module.bias.data, 0.0)


# 呼叫生成器和判別器到GPU
G_A2B = ResnetGenerator(input_nc=3, output_nc=3, n_blocks=6, ngf=64).to(device)
G_B2A = ResnetGenerator(input_nc=3, output_nc=3, n_blocks=6, ngf=64).to(device)

#Discriminator for Domain A
D_A = PatchDiscriminator(input_nc=3, ndf=64, n_layers=3).to(device)
#Discriminator for Domain B
D_B = PatchDiscriminator(input_nc=3, ndf=64, n_layers=3).to(device)

#權重初始化
G_A2B.apply(init_weights)
G_B2A.apply(init_weights)
D_A.apply(init_weights)
D_B.apply(init_weights)
print("Networks initialized and moved to device:")
print(f"G_A2B on {device}")
print(f"G_B2A on {device}")
print(f"D_A on {device}")
print(f"D_B on {device}")
# Out:
# Networks initialized and moved to device:
# G_A2B on cuda
# G_B2A on cuda
# D_A on cuda
# D_B on cuda

# %% [markdown]
# ## 5. Losses, Optimizers
#
# Wire up the adversarial, cycle, and identity losses plus the optimizers for each network.
# **Checklist**
# - [ ] Design GAN loss  and `nn.L1Loss` for cycle/identity terms.
# - [ ] Create two Adam optimizers: one shared for both generators, one per discriminator (or separate if you prefer).
#
# - [ ] Track/log learning rates in case you use schedulers.

# %%
class GANLoss(nn.Module):
    def __init__(self, use_lsgan: bool = True):
        super().__init__()

        # 根據 LSGAN 或 Vanilla GAN 設定目標標籤
        if use_lsgan:
            # LSGAN: Real label = 1.0, Fake label = 0.0
            self.register_buffer('real_label', torch.tensor(1.0))
            self.register_buffer('fake_label', torch.tensor(0.0))
            self.loss = nn.MSELoss()
        else:
            # Vanilla GAN: Real label = 1.0, Fake label = 0.0
            self.register_buffer('real_label', torch.tensor(1.0))
            self.register_buffer('fake_label', torch.tensor(0.0))
            self.loss = nn.BCELoss()

        self.use_lsgan = use_lsgan

    def get_target_tensor(self, prediction: torch.Tensor, target_is_real: bool) -> torch.Tensor:
        #根據輸入的預測張量 (prediction) 的形狀，創建一個相同大小全為1或0的張量。
        if target_is_real:
            target_tensor = self.real_label
        else:
            target_tensor = self.fake_label
        target_tensor = target_tensor.expand_as(prediction)
        return target_tensor.to(prediction.device)

    def forward(self, prediction: torch.Tensor, target_is_real: bool):
        #計算對抗性損失。
        #獲取預測結果張量 (e.g., 全 1.0 或 全 0.0)
        target_tensor = self.get_target_tensor(prediction, target_is_real)

        # 計算損失
        return self.loss(prediction, target_tensor)


# CycleGAN 論文中用於儲存和重放先前生成圖像的緩衝區
class ImagePool:
    def __init__(self, pool_size: int = 50):
        #存50張舊的圖在cpu
        self.pool_size = pool_size
        if pool_size > 0:
            self.num_imgs = 0
            self.images = []

    def query(self, images: torch.Tensor) -> torch.Tensor:
        #以 50% 的機率返回緩衝區中的舊圖像回傳包含新圖像或舊圖像的 Batch
        if self.pool_size == 0:
            # 如果緩衝區大小為 0，直接返回新圖像
            return images

        return_images = []
        for image in images:
            image = torch.unsqueeze(image.data, 0) # 轉換為 (1, C, H, W)

            if self.num_imgs < self.pool_size:
                # 緩衝區未滿，直接加入新圖像
                self.num_imgs = self.num_imgs + 1
                self.images.append(image)
                return_images.append(image)
            else:
                p = random.uniform(0, 1)
                if p > 0.5:
                    # 50% 機率：從緩衝區中隨機替換一張圖像，並返回被替換的舊圖像
                    random_idx = random.randint(0, self.pool_size - 1)
                    temp = self.images[random_idx].clone()
                    self.images[random_idx] = image # 用新圖像替換
                    return_images.append(temp)     # 返回舊圖像
                else:
                    # 50% 機率直接返回新圖像，但不將其放入緩衝區
                    return_images.append(image)

        # 將所有單張圖像重新堆疊成一個 Batch
        return_images = torch.cat(return_images, 0)
        return return_images

# 學習率調整器實現 (LRScheduler)
#https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class LRScheduler:
    #用於 CycleGAN 的線性學習率衰減調度器。在 `decay_start_epoch` 之前保持初始學習率，然後線性衰減至 0。
    def __init__(self, optimizer: optim.Optimizer, n_epochs: int, decay_start_epoch: int):
        """
        Args:
            optimizer (optim.Optimizer): 要調整學習率的優化器。
            n_epochs (int): 總訓練 epochs 數量 (例如 200)。
            decay_start_epoch (int): 開始線性衰減的 epoch 數 (例如 100)。
        """
        self.optimizer = optimizer
        self.n_epochs = n_epochs
        self.decay_start_epoch = decay_start_epoch
        self.initial_lrs = [param_group['lr'] for param_group in optimizer.param_groups]

        # 總共需要衰減的 epochs 數
        self.n_decay_epochs = n_epochs - decay_start_epoch
        if self.n_decay_epochs <= 0:
            self.n_decay_epochs = 1 # 避免除以零

    def step(self, epoch: int):
        """
        根據當前 epoch 調整學習率。
        """
        # 判斷是否進入衰減階段
        if epoch < self.decay_start_epoch:
            return

        #計算衰減進度
        decay_progress = (epoch - self.decay_start_epoch) / self.n_decay_epochs

        # 線性衰減
        for i, param_group in enumerate(self.optimizer.param_groups):
            initial_lr = self.initial_lrs[i]
            # 新的學習率
            new_lr = initial_lr * (1.0 - decay_progress)
            param_group['lr'] = new_lr


#根據 LSGAN 設定目標標籤
criterionGAN = GANLoss(use_lsgan=True)

# L1 Loss
criterionL1 = nn.L1Loss()


# 生成器：合併兩個生成器的參數
G_params = list(G_A2B.parameters()) + list(G_B2A.parameters())
optim_G = optim.Adam(G_params, lr=cfg.lr, betas=(cfg.beta1, cfg.beta2))

# 判別器：各自一個 optimizer
optim_D_A = optim.Adam(D_A.parameters(), lr=cfg.lr, betas=(cfg.beta1, cfg.beta2))
optim_D_B = optim.Adam(D_B.parameters(), lr=cfg.lr, betas=(cfg.beta1, cfg.beta2))

# 呼叫LRScheduler
lr_scheduler_G = LRScheduler(optim_G, cfg.epochs, cfg.decay_start_epoch)
lr_scheduler_D_A = LRScheduler(optim_D_A, cfg.epochs, cfg.decay_start_epoch)
lr_scheduler_D_B = LRScheduler(optim_D_B, cfg.epochs, cfg.decay_start_epoch)

# 呼叫image buffer
fake_A_pool = ImagePool(pool_size=50)
fake_B_pool = ImagePool(pool_size=50)

print(f"GAN Loss (LSGAN) initialized: {criterionGAN}")
print(f"L1 Loss initialized: {criterionL1}")
print(f"Generator Optimizer (Adam) created with LR={cfg.lr}")
print("Discriminator Optimizers (Adam) created.")
print(f"ImagePool (A & B) created with size 50.")
print(f"LRSchedulers initialized for linear decay from epoch {cfg.decay_start_epoch} to {cfg.epochs}.")
# Out:
# GAN Loss (LSGAN) initialized: GANLoss(
#   (loss): MSELoss()
# )
# L1 Loss initialized: L1Loss()
# Generator Optimizer (Adam) created with LR=0.0002
# Discriminator Optimizers (Adam) created.
# ImagePool (A & B) created with size 50.
# LRSchedulers initialized for linear decay from epoch 100 to 30.

# %% [markdown]
# ## 6. Training
#
# Combine everything into a full CycleGAN training loop. Use `tqdm` (or your preferred logger) to monitor generator/discriminator losses, periodically export translation grids, and save checkpoints on schedule.
#
# **Checklist**
# - [ ] Zip/iterate over both domain dataloaders, moving tensors to `device`.
# - [ ] Update both generators jointly, then each discriminator separately (with buffers).
# - [ ] Log running averages of `loss_G`, `loss_D_A`, and `loss_D_B`.

# %%
def save_grid(epoch: int, step: int, images: torch.Tensor, name: str, outputs_dir: Path):
    #將圖像張量保存
    # epoch : 當前的 epoch 數。
    # step : 當前的步數 (可選，如果為 None 則不包含在文件名中)。
    # images : 要保存的圖像張量
    # name: 網格的基礎名稱 (e.g., 'val_A2B')。
    # outputs_dir: 輸出目錄的路徑。

    if images is None:
        print(f"--- [Log Warning] Cannot save {name}: images tensor is None.")
        return

    # 確保輸出目錄存在
    outputs_dir.mkdir(parents=True, exist_ok=True)

    # 檔案命名
    if step is not None:
        filename = f"{name}_epoch_{epoch}_step_{step}.png"
    else:
        filename = f"{name}_epoch_{epoch}.png"

    filepath = outputs_dir / filename

    # 使用 save_image 函數保存圖像
    # 自動對圖像進行denormalize ([ -1, 1 ] -> [ 0, 1 ])
    try:
        save_image(images, filepath, normalize=True, nrow=images.size(0) // 3)
        print(f"--- [Log Success] Saved image grid to {filepath.resolve()}")
    except Exception as e:
        print(f"--- [Log Error] Failed to save image grid {filepath.name}: {e}")

# 保存模型參數
def save_checkpoint(epoch: int, net: nn.Module, name: str, opt: torch.optim.Optimizer, outputs_dir: Path):

        # epoch: 當前的 epoch 數。
        # net : 要保存的模型。
        # name: 模型的名稱 (e.g., 'G_A2B', 'D_A')。
        # opt : 要保存的optimizer狀態。
        # outputs_dir : 輸出目錄的路徑。

    # 確保輸出目錄存在
    outputs_dir = Path(outputs_dir)
    outputs_dir.mkdir(parents=True, exist_ok=True)

    # 定義檔案路徑
    filename = f"{name}_epoch_{epoch}.pth"
    filepath = outputs_dir / filename

    # 建立要保存的狀態字典
    checkpoint_state = {
        'epoch': epoch,
        'state_dict': net.state_dict(),
        'optimizer': opt.state_dict(),
    }

    # 保存檢查點
    try:
        torch.save(checkpoint_state, filepath)
        print(f"--- [Checkpoint Success] Saved {name} checkpoint to {filepath.resolve()}")
    except Exception as e:
        print(f"--- [Checkpoint Error] Failed to save {name} checkpoint: {e}")

# --- 3. 檢查點加載函數 (load_checkpoint) (可選，但推薦) ---
def load_checkpoint(net: nn.Module, opt: torch.optim.Optimizer, name: str, outputs_dir: Path, epoch: int = 'latest') -> int:

    #加載網路模型和優化器的狀態字典。
    # net : 要加載狀態的網路模型。
    # opt : 要加載狀態的優化器。
    # name : 模型的名稱。
    # outputs_dir : 檢查點所在的目錄。
    # epoch : 要加載的 epoch 數或 'latest'。

    outputs_dir = Path(outputs_dir)
    if epoch == 'latest':
        # 在實際應用中，會查找目錄中最新的檢查點
        print(f"--- [Load Checkpoint] Simulating loading latest checkpoint for {name}...")
        return 0 # 模擬從 0 epoch 開始

    filename = f"{name}_epoch_{epoch}.pth"
    filepath = outputs_dir / filename

    if not filepath.exists():
        print(f"--- [Load Checkpoint] Warning: Checkpoint file not found: {filepath.resolve()}")
        return 0

    try:
        # 使用 map_location=device 來確保在正確的設備上加載
        checkpoint = torch.load(filepath, map_location=device)
        net.load_state_dict(checkpoint['state_dict'])
        opt.load_state_dict(checkpoint['optimizer'])
        start_epoch = checkpoint.get('epoch', 0)

        print(f"--- [Load Checkpoint Success] Loaded {name} from epoch {start_epoch}.")
        return start_epoch
    except Exception as e:
        print(f"--- [Load Checkpoint Error] Failed to load checkpoint {filepath.name}: {e}")
        return 0
global_step = 0
print(f"Starting CycleGAN Training for {cfg.epochs} epochs on {device}...")




resume_epoch = 0  # 預設從 0 開始

resume_epoch = load_checkpoint(G_A2B, optim_G,   'G_A2B', cfg.checkpoints, epoch=30)
load_checkpoint(G_B2A, optim_G,   'G_B2A', cfg.checkpoints, epoch=30)
load_checkpoint(D_A,   optim_D_A, 'D_A',   cfg.checkpoints, epoch=30)
load_checkpoint(D_B,   optim_D_B, 'D_B',   cfg.checkpoints, epoch=30)

print(f"Resuming training from epoch {resume_epoch}...")
for epoch in range(resume_epoch + 1, cfg.epochs + 1):

    # 使用 tqdm 顯示進度
    # 我們假設 trainA_loader 和 trainB_loader 長度相同
    data_iterator = zip(trainA_loader, trainB_loader)

    # 實際應用中，應將 tqdm(data_iterator) 包裹起來
    # 這裡我們使用一個簡單的計數器模擬步進

    epoch_start_time = time.time()

    # 假設這是一個被 tqdm 包裹的迴圈
    for i, ((real_A, _), (real_B, _)) in enumerate(data_iterator):

        # 1. 數據移動到設備
        real_A = real_A.to(device)
        real_B = real_B.to(device)

        # =========================================================
        # === A. 更新生成器 G_A2B & G_B2A ===
        # =========================================================
        optim_G.zero_grad()

        # 1. Identity Loss (I): 保持風格不變
        # I_A: G_B2A(real_A) 應該接近 real_A
        id_A = G_B2A(real_A)
        loss_id_A = criterionL1(id_A, real_A) * cfg.lambda_idt

        # I_B: G_A2B(real_B) 應該接近 real_B
        id_B = G_A2B(real_B)
        loss_id_B = criterionL1(id_B, real_B) * cfg.lambda_idt

        # 2. GAN Loss (G): 欺騙判別器
        # G_A2B(A) 應該被 D_B 判斷為 Real
        fake_B = G_A2B(real_A)
        pred_fake_B = D_B(fake_B)
        loss_GAN_A2B = criterionGAN(pred_fake_B, True) # True label

        # G_B2A(B) 應該被 D_A 判斷為 Real
        fake_A = G_B2A(real_B)
        pred_fake_A = D_A(fake_A)
        loss_GAN_B2A = criterionGAN(pred_fake_A, True) # True label

        # 3. Cycle Consistency Loss (C): 循環重建
        # C_A: A -> B -> A 應該等於 A
        rec_A = G_B2A(fake_B) # G_B2A(G_A2B(real_A))
        loss_cycle_A = criterionL1(rec_A, real_A) * cfg.lambda_cyc

        # C_B: B -> A -> B 應該等於 B
        rec_B = G_A2B(fake_A) # G_A2B(G_B2A(real_B))
        loss_cycle_B = criterionL1(rec_B, real_B) * cfg.lambda_cyc

        # 4. 總生成器損失
        loss_G = loss_GAN_A2B + loss_GAN_B2A + \
                 loss_cycle_A + loss_cycle_B + \
                 loss_id_A + loss_id_B

        # 5. 反向傳播與優化
        loss_G.backward()
        optim_G.step()


        # =========================================================
        # === B. 更新判別器 D_A ===
        # =========================================================
        optim_D_A.zero_grad()

        # 1. Real Loss (D_A 判斷真實 A)
        pred_real_A = D_A(real_A)
        loss_D_real_A = criterionGAN(pred_real_A, True)

        # 2. Fake Loss (D_A 判斷虛假 A - 使用緩衝區)
        # 從 ImagePool 中取樣 fake_A，並 detach 以防止梯度流回 G_B2A
        fake_A_sampled = fake_A_pool.query(fake_A)
        pred_fake_A_sampled = D_A(fake_A_sampled.detach())
        loss_D_fake_A = criterionGAN(pred_fake_A_sampled, False)

        # 3. 總 D_A 損失 (除以 2 是常見做法)
        loss_D_A = (loss_D_real_A + loss_D_fake_A) * 0.5

        # 4. 反向傳播與優化
        loss_D_A.backward()
        optim_D_A.step()


        # =========================================================
        # === C. 更新判別器 D_B ===
        # =========================================================
        optim_D_B.zero_grad()

        # 1. Real Loss (D_B 判斷真實 B)
        pred_real_B = D_B(real_B)
        loss_D_real_B = criterionGAN(pred_real_B, True)

        # 2. Fake Loss (D_B 判斷虛假 B - 使用緩衝區)
        # 從 ImagePool 中取樣 fake_B，並 detach 以防止梯度流回 G_A2B
        fake_B_sampled = fake_B_pool.query(fake_B)
        pred_fake_B_sampled = D_B(fake_B_sampled.detach())
        loss_D_fake_B = criterionGAN(pred_fake_B_sampled, False)

        # 3. 總 D_B 損失
        loss_D_B = (loss_D_real_B + loss_D_fake_B) * 0.5

        # 4. 反向傳播與優化
        loss_D_B.backward()
        optim_D_B.step()


        # =========================================================
        # === D. 日誌與檢查點 (Log & Checkpoint) ===
        # =========================================================
        global_step += 1

        # TODO: update tqdm / write scalars to TensorBoard
        if i % 2 == 0: # 模擬每 N 步寫入日誌
             print(f"[Epoch {epoch}/{cfg.epochs}] [Step {i}] G_Loss: {loss_G.item():.4f}, D_A Loss: {loss_D_A.item():.4f}, D_B Loss: {loss_D_B.item():.4f}")

        # TODO: save periodic samples via `save_grid` (例如每 100 步)
        if global_step % 100 == 0:
             # 這裡可以調用 save_grid(epoch, global_step, [real_A, fake_B, rec_A, real_B, fake_A, rec_B])
             # 為了簡化，我們只調用模擬函數
              fake_B = G_A2B(real_A)
              rec_A  = G_B2A(fake_B)

              # B → A → B
              fake_A = G_B2A(real_B)
              rec_B  = G_A2B(fake_A)

              # build image grid (A→fakeB→recA | B→fakeA→recB)
              combined_images = torch.cat([
                  real_A[:cfg.val_fixed_n],
                  fake_B[:cfg.val_fixed_n],
                  rec_A[:cfg.val_fixed_n],

                  real_B[:cfg.val_fixed_n],
                  fake_A[:cfg.val_fixed_n],
                  rec_B[:cfg.val_fixed_n]
              ], dim=0)

              save_grid(
                epoch=epoch,
                step=global_step,
                images=combined_images.cpu(),
                name='A2B_B2A_Sample',
                outputs_dir=Path(cfg.outputs)/ "train"
              )


    # === End of epoch ===
    print(f"Epoch {epoch} finished in {time.time() - epoch_start_time:.2f}s.")
    if epoch % 10 == 0:
        save_checkpoint(epoch, G_A2B, 'G_A2B', optim_G, cfg.checkpoints)
        save_checkpoint(epoch, G_B2A, 'G_B2A', optim_G, cfg.checkpoints)
        save_checkpoint(epoch, D_A,   'D_A',   optim_D_A, cfg.checkpoints)
        save_checkpoint(epoch, D_B,   'D_B',   optim_D_B, cfg.checkpoints)

print("Training finished.")
# Out:
# Starting CycleGAN Training for 30 epochs on cuda...
# --- [Load Checkpoint] Warning: Checkpoint file not found: /home/vicky/ML-HW8/checkpoints/G_A2B_epoch_30.pth
# --- [Load Checkpoint] Warning: Checkpoint file not found: /home/vicky/ML-HW8/checkpoints/G_B2A_epoch_30.pth
# --- [Load Checkpoint] Warning: Checkpoint file not found: /home/vicky/ML-HW8/checkpoints/D_A_epoch_30.pth
# --- [Load Checkpoint] Warning: Checkpoint file not found: /home/vicky/ML-HW8/checkpoints/D_B_epoch_30.pth
# Resuming training from epoch 0...
# [Epoch 1/30] [Step 0] G_Loss: 23.1250, D_A Loss: 2.2446, D_B Loss: 1.8983
# [Epoch 1/30] [Step 2] G_Loss: 22.9556, D_A Loss: 3.1957, D_B Loss: 1.9032
# [Epoch 1/30] [Step 4] G_Loss: 21.2028, D_A Loss: 1.5285, D_B Loss: 1.6215
# [Epoch 1/30] [Step 6] G_Loss: 18.5904, D_A Loss: 2.1701, D_B Loss: 1.4826
# [Epoch 1/30] [Step 8] G_Loss: 18.3348, D_A Loss: 1.9844, D_B Loss: 1.1946
# [Epoch 1/30] [Step 10] G_Loss: 14.7758, D_A Loss: 1.1438, D_B Loss: 1.8972
# [Epoch 1/30] [Step 12] G_Loss: 13.3750, D_A Loss: 1.1206, D_B Loss: 1.0363
# [Epoch 1/30] [Step 14] G_Loss: 14.8264, D_A Loss: 1.4846, D_B Loss: 1.8512
# [Epoch 1/30] [Step 16] G_Loss: 16.2686, D_A Loss: 1.1145, D_B Loss: 1.1628
# [Epoch 1/30] [Step 18] G_Loss: 13.2789, D_A Loss: 0.8127, D_B Loss: 0.9324
# [Epoch 1/30] [Step 20] G_Loss: 15.5954, D_A Loss: 0.7812, D_B Loss: 0.6956
# [Epoch 1/30] [Step 22] G_Loss: 14.5866, D_A Loss: 1.1427, D_B Loss: 0.9746
# [Epoch 1/30] [Step 24] G_Loss: 10.7789, D_A Loss: 0.9077, D_B Loss: 0.8605
# [Epoch 1/30] [Step 26] G_Loss: 10.9018, D_A Loss: 0.6908, D_B Loss: 0.6422
# [Epoch 1/30] [Step 28] G_Loss: 19.6745, D_A Loss: 0.7065, D_B Loss: 0.6535
# [Epoch 1/30] [Step 30] G_Loss: 12.2915, D_A Loss: 0.5962, D_B Loss: 0.6467
# [Epoch 1/30] [Step 32] G_Loss: 10.3208, D_A Loss: 0.9806, D_B Loss: 0.5427
# [Epoch 1/30] [Step 34] G_Loss: 10.3637, D_A Loss: 0.8745, D_B Loss: 0.3952
# [Epoch 1/30] [Step 36] G_Loss: 10.4643, D_A Loss: 0.6229, D_B Loss: 0.5701
# [Epoch 1/30] [Step 38] G_Loss: 11.1852, D_A Loss: 0.4753, D_B Loss: 0.5532
# [Epoch 1/30] [Step 40] G_Loss: 10.8410, D_A Loss: 0.5566, D_B Loss: 0.6916
# [Epoch 2/30] [Step 350] G_Loss: 8.3341, D_A Loss: 0.1605, D_B Loss: 0.2667
# [Epoch 2/30] [Step 352] G_Loss: 8.2982, D_A Loss: 0.2230, D_B Loss: 0.2975
# [Epoch 2/30] [Step 354] G_Loss: 9.4696, D_A Loss: 0.1615, D_B Loss: 0.3570
# [Epoch 2/30] [Step 356] G_Loss: 8.8105, D_A Loss: 0.1826, D_B Loss: 0.3057
# [Epoch 2/30] [Step 358] G_Loss: 6.6494, D_A Loss: 0.2755, D_B Loss: 0.4482
# [Epoch 2/30] [Step 360] G_Loss: 7.6659, D_A Loss: 0.1826, D_B Loss: 0.2298
# [Epoch 2/30] [Step 362] G_Loss: 7.3979, D_A Loss: 0.5371, D_B Loss: 0.3215
# [Epoch 2/30] [Step 364] G_Loss: 9.7294, D_A Loss: 0.3842, D_B Loss: 0.2545
# [Epoch 2/30] [Step 366] G_Loss: 7.2532, D_A Loss: 0.1844, D_B Loss: 0.2044
# [Epoch 2/30] [Step 368] G_Loss: 8.3271, D_A Loss: 0.1634, D_B Loss: 0.1799
# [Epoch 2/30] [Step 370] G_Loss: 9.9021, D_A Loss: 0.1645, D_B Loss: 0.3071
# [Epoch 2/30] [Step 372] G_Loss: 9.2613, D_A Loss: 0.1418, D_B Loss: 0.2308
# [Epoch 2/30] [Step 374] G_Loss: 5.9476, D_A Loss: 0.2354, D_B Loss: 0.1797
# [Epoch 2/30] [Step 376] G_Loss: 8.5086, D_A Loss: 0.2514, D_B Loss: 0.1687
# [Epoch 2/30] [Step 378] G_Loss: 6.4304, D_A Loss: 0.1236, D_B Loss: 0.1974
# [Epoch 2/30] [Step 380] G_Loss: 7.7170, D_A Loss: 0.2747, D_B Loss: 0.4117
# [Epoch 2/30] [Step 382] G_Loss: 11.3515, D_A Loss: 0.2735, D_B Loss: 0.3582
# [Epoch 2/30] [Step 384] G_Loss: 9.2838, D_A Loss: 0.4159, D_B Loss: 0.3160
# [Epoch 2/30] [Step 386] G_Loss: 5.7123, D_A Loss: 0.1753, D_B Loss: 0.2597
# [Epoch 2/30] [Step 388] G_Loss: 8.7675, D_A Loss: 0.4908, D_B Loss: 0.3156
# [Epoch 2/30] [Step 390] G_Loss: 6.3001, D_A Loss: 0.3094, D_B Loss: 0.1835
# [Epoch 2/30] [Step 392] G_Loss: 7.9827, D_A Loss: 0.1559, D_B Loss: 0.1206
# [Epoch 2/30] [Step 394] G_Loss: 10.5844, D_A Loss: 0.1991, D_B Loss: 0.2650
# [Epoch 2/30] [Step 396] G_Loss: 7.4698, D_A Loss: 0.2017, D_B Loss: 0.1568
# [Epoch 2/30] [Step 398] G_Loss: 9.1219, D_A Loss: 0.2467, D_B Loss: 0.2704
# --- [Log Success] Saved image grid to /home/vicky/ML-HW8/outputs/train/A2B_B2A_Sample_epoch_2_step_800.png
# Epoch 2 finished in 205.38s.
# [Epoch 3/30] [Step 0] G_Loss: 9.1181, D_A Loss: 0.3044, D_B Loss: 0.2035
# [Epoch 3/30] [Step 166] G_Loss: 10.5403, D_A Loss: 0.2365, D_B Loss: 0.2217
# [Epoch 3/30] [Step 168] G_Loss: 7.7181, D_A Loss: 0.2276, D_B Loss: 0.1933
# [Epoch 3/30] [Step 170] G_Loss: 9.8583, D_A Loss: 0.2097, D_B Loss: 0.3664
# [Epoch 3/30] [Step 172] G_Loss: 11.5946, D_A Loss: 0.2180, D_B Loss: 0.5324
# [Epoch 3/30] [Step 174] G_Loss: 7.4660, D_A Loss: 0.2493, D_B Loss: 0.2717
# [Epoch 3/30] [Step 176] G_Loss: 6.5515, D_A Loss: 0.1976, D_B Loss: 0.1264
# [Epoch 3/30] [Step 178] G_Loss: 8.4675, D_A Loss: 0.1952, D_B Loss: 0.1623
# [Epoch 3/30] [Step 180] G_Loss: 11.4960, D_A Loss: 0.1768, D_B Loss: 0.1178
# [Epoch 3/30] [Step 182] G_Loss: 10.3975, D_A Loss: 0.4018, D_B Loss: 0.1785
# [Epoch 3/30] [Step 184] G_Loss: 9.1978, D_A Loss: 0.1614, D_B Loss: 0.1791
# [Epoch 3/30] [Step 186] G_Loss: 5.6683, D_A Loss: 0.1472, D_B Loss: 0.2224
# [Epoch 3/30] [Step 188] G_Loss: 6.6692, D_A Loss: 0.2418, D_B Loss: 0.1542
# [Epoch 3/30] [Step 190] G_Loss: 8.6975, D_A Loss: 0.3366, D_B Loss: 0.1763
# [Epoch 3/30] [Step 192] G_Loss: 6.9435, D_A Loss: 0.2607, D_B Loss: 0.2599
# [Epoch 3/30] [Step 194] G_Loss: 6.6130, D_A Loss: 0.2433, D_B Loss: 0.1937
# [Epoch 3/30] [Step 196] G_Loss: 10.1468, D_A Loss: 0.2524, D_B Loss: 0.0819
# [Epoch 3/30] [Step 198] G_Loss: 8.8706, D_A Loss: 0.2456, D_B Loss: 0.2295
# --- [Log Success] Saved image grid to /home/vicky/ML-HW8/outputs/train/A2B_B2A_Sample_epoch_3_step_1000.png
# [Epoch 3/30] [Step 200] G_Loss: 8.9277, D_A Loss: 0.2378, D_B Loss: 0.3546
# [Epoch 3/30] [Step 202] G_Loss: 7.3505, D_A Loss: 0.2426, D_B Loss: 0.2941
# [Epoch 3/30] [Step 204] G_Loss: 6.6561, D_A Loss: 0.3663, D_B Loss: 0.2395
# [Epoch 3/30] [Step 206] G_Loss: 7.3358, D_A Loss: 0.2446, D_B Loss: 0.2833
# [Epoch 3/30] [Step 208] G_Loss: 6.3701, D_A Loss: 0.1569, D_B Loss: 0.1779
# [Epoch 3/30] [Step 210] G_Loss: 7.2983, D_A Loss: 0.3084, D_B Loss: 0.4212
# [Epoch 3/30] [Step 212] G_Loss: 8.4630, D_A Loss: 0.2302, D_B Loss: 0.3776
# [Epoch 3/30] [Step 214] G_Loss: 8.9404, D_A Loss: 0.1526, D_B Loss: 0.3851
# [Epoch 3/30] [Step 216] G_Loss: 7.0460, D_A Loss: 0.3204, D_B Loss: 0.3459
# [Epoch 3/30] [Step 218] G_Loss: 6.7688, D_A Loss: 0.2538, D_B Loss: 0.2001
# [Epoch 3/30] [Step 276] G_Loss: 8.3676, D_A Loss: 0.2092, D_B Loss: 0.3464
# [Epoch 3/30] [Step 278] G_Loss: 10.2939, D_A Loss: 0.4144, D_B Loss: 0.4072
# [Epoch 3/30] [Step 280] G_Loss: 5.8522, D_A Loss: 0.2779, D_B Loss: 0.2487
# [Epoch 3/30] [Step 282] G_Loss: 6.7884, D_A Loss: 0.3640, D_B Loss: 0.0965
# [Epoch 3/30] [Step 284] G_Loss: 7.1075, D_A Loss: 0.2076, D_B Loss: 0.1305
# [Epoch 3/30] [Step 286] G_Loss: 7.3621, D_A Loss: 0.1909, D_B Loss: 0.1880
# [Epoch 3/30] [Step 288] G_Loss: 5.9645, D_A Loss: 0.1006, D_B Loss: 0.1658
# [Epoch 3/30] [Step 290] G_Loss: 6.4786, D_A Loss: 0.1445, D_B Loss: 0.1247
# [Epoch 3/30] [Step 292] G_Loss: 5.4362, D_A Loss: 0.2056, D_B Loss: 0.1321
# [Epoch 3/30] [Step 294] G_Loss: 8.2426, D_A Loss: 0.2033, D_B Loss: 0.3917
# [Epoch 3/30] [Step 296] G_Loss: 6.7449, D_A Loss: 0.3298, D_B Loss: 0.3044
# [Epoch 3/30] [Step 298] G_Loss: 13.6375, D_A Loss: 0.1735, D_B Loss: 0.3078
# --- [Log Success] Saved image grid to /home/vicky/ML-HW8/outputs/train/A2B_B2A_Sample_epoch_3_step_1100.png
# [Epoch 3/30] [Step 300] G_Loss: 9.7599, D_A Loss: 0.2453, D_B Loss: 0.1072
# [Epoch 3/30] [Step 302] G_Loss: 7.1543, D_A Loss: 0.4310, D_B Loss: 0.5910
# [Epoch 3/30] [Step 304] G_Loss: 7.0109, D_A Loss: 0.3243, D_B Loss: 0.5367
# [Epoch 3/30] [Step 306] G_Loss: 7.6205, D_A Loss: 0.2322, D_B Loss: 0.1195
# [Epoch 3/30] [Step 308] G_Loss: 6.3734, D_A Loss: 0.1937, D_B Loss: 0.0846
# [Epoch 3/30] [Step 310] G_Loss: 5.5468, D_A Loss: 0.2063, D_B Loss: 0.1703
# [Epoch 3/30] [Step 312] G_Loss: 7.8427, D_A Loss: 0.3099, D_B Loss: 0.2183
# [Epoch 3/30] [Step 314] G_Loss: 8.3742, D_A Loss: 0.2432, D_B Loss: 0.2986
# [Epoch 3/30] [Step 316] G_Loss: 7.2883, D_A Loss: 0.2290, D_B Loss: 0.0971
# [Epoch 3/30] [Step 318] G_Loss: 10.0146, D_A Loss: 0.1211, D_B Loss: 0.2767
# [Epoch 3/30] [Step 320] G_Loss: 11.3962, D_A Loss: 0.2275, D_B Loss: 0.2477
# [Epoch 3/30] [Step 322] G_Loss: 7.8114, D_A Loss: 0.5977, D_B Loss: 0.3214
# [Epoch 3/30] [Step 324] G_Loss: 7.6299, D_A Loss: 0.3312, D_B Loss: 0.2910
# [Epoch 3/30] [Step 326] G_Loss: 5.0532, D_A Loss: 0.3888, D_B Loss: 0.2788
# [Epoch 3/30] [Step 328] G_Loss: 9.0971, D_A Loss: 0.2037, D_B Loss: 0.2023
# [Epoch 3/30] [Step 330] G_Loss: 7.8399, D_A Loss: 0.2148, D_B Loss: 0.2191
# [Epoch 3/30] [Step 332] G_Loss: 17.3107, D_A Loss: 0.1867, D_B Loss: 0.1234
# [Epoch 3/30] [Step 334] G_Loss: 9.0305, D_A Loss: 0.1718, D_B Loss: 0.2606
# [Epoch 3/30] [Step 336] G_Loss: 9.8992, D_A Loss: 0.1794, D_B Loss: 0.2515
# [Epoch 3/30] [Step 338] G_Loss: 7.7113, D_A Loss: 0.1738, D_B Loss: 0.2820
# [Epoch 3/30] [Step 340] G_Loss: 13.6718, D_A Loss: 0.1171, D_B Loss: 0.3229
# [Epoch 3/30] [Step 342] G_Loss: 6.4709, D_A Loss: 0.4523, D_B Loss: 0.3304
# [Epoch 3/30] [Step 344] G_Loss: 7.0159, D_A Loss: 0.2612, D_B Loss: 0.1605
# [Epoch 3/30] [Step 346] G_Loss: 10.2638, D_A Loss: 0.1217, D_B Loss: 0.3582
# [Epoch 3/30] [Step 348] G_Loss: 6.1316, D_A Loss: 0.3552, D_B Loss: 0.3113
# [Epoch 3/30] [Step 350] G_Loss: 7.9295, D_A Loss: 0.1694, D_B Loss: 0.1869
# [Epoch 3/30] [Step 352] G_Loss: 11.1260, D_A Loss: 0.1642, D_B Loss: 0.1183
# [Epoch 3/30] [Step 354] G_Loss: 9.0563, D_A Loss: 0.2054, D_B Loss: 0.2489
# [Epoch 3/30] [Step 356] G_Loss: 7.9354, D_A Loss: 0.1641, D_B Loss: 0.2065
# [Epoch 3/30] [Step 358] G_Loss: 6.6856, D_A Loss: 0.2567, D_B Loss: 0.1974
# [Epoch 3/30] [Step 360] G_Loss: 8.0672, D_A Loss: 0.2104, D_B Loss: 0.2789
# [Epoch 3/30] [Step 362] G_Loss: 6.3397, D_A Loss: 0.1003, D_B Loss: 0.2985
# [Epoch 3/30] [Step 364] G_Loss: 9.6309, D_A Loss: 0.2410, D_B Loss: 0.1403
# [Epoch 3/30] [Step 366] G_Loss: 8.7086, D_A Loss: 0.2776, D_B Loss: 0.0997
# [Epoch 3/30] [Step 368] G_Loss: 6.4101, D_A Loss: 0.3393, D_B Loss: 0.2288
# [Epoch 3/30] [Step 370] G_Loss: 9.2590, D_A Loss: 0.5033, D_B Loss: 0.1605
# [Epoch 3/30] [Step 372] G_Loss: 8.0549, D_A Loss: 0.2815, D_B Loss: 0.2875
# [Epoch 3/30] [Step 374] G_Loss: 6.6470, D_A Loss: 0.2397, D_B Loss: 0.3122
# [Epoch 3/30] [Step 376] G_Loss: 9.6292, D_A Loss: 0.1194, D_B Loss: 0.1449
# [Epoch 3/30] [Step 378] G_Loss: 6.6635, D_A Loss: 0.2096, D_B Loss: 0.2146
# [Epoch 3/30] [Step 380] G_Loss: 7.5260, D_A Loss: 0.1566, D_B Loss: 0.2275
# [Epoch 3/30] [Step 382] G_Loss: 6.2582, D_A Loss: 0.0885, D_B Loss: 0.2731
# [Epoch 3/30] [Step 384] G_Loss: 9.6495, D_A Loss: 0.1385, D_B Loss: 0.1735
# [Epoch 30/30] [Step 392] G_Loss: 6.0670, D_A Loss: 0.1154, D_B Loss: 0.2557
# [Epoch 30/30] [Step 394] G_Loss: 5.1476, D_A Loss: 0.2101, D_B Loss: 0.2125
# [Epoch 30/30] [Step 396] G_Loss: 6.5141, D_A Loss: 0.0827, D_B Loss: 0.2464
# [Epoch 30/30] [Step 398] G_Loss: 6.6875, D_A Loss: 0.0603, D_B Loss: 0.1308
# --- [Log Success] Saved image grid to /home/vicky/ML-HW8/outputs/train/A2B_B2A_Sample_epoch_30_step_12000.png
# Epoch 30 finished in 206.01s.
# --- [Checkpoint Success] Saved G_A2B checkpoint to /home/vicky/ML-HW8/checkpoints/G_A2B_epoch_30.pth
# --- [Checkpoint Success] Saved G_B2A checkpoint to /home/vicky/ML-HW8/checkpoints/G_B2A_epoch_30.pth
# --- [Checkpoint Success] Saved D_A checkpoint to /home/vicky/ML-HW8/checkpoints/D_A_epoch_30.pth
# --- [Checkpoint Success] Saved D_B checkpoint to /home/vicky/ML-HW8/checkpoints/D_B_epoch_30.pth
# Training finished.

# %% [markdown]
# ## 7. Validation Gallery
#
# Hold out a few samples from each domain, translate them with the current generators, then compose `A → B → A` and `B → A → B` grids. Save the outputs under `outputs/val` so they can be included in your report.
#
# **Checklist**
# - [ ] Switch models to `.eval()` and wrap evaluation in `torch.no_grad()`.
# - [ ] Reuse the cached `fixed_A` / `fixed_B` batches for consistent comparisons.
# - [ ] Save grids as `val_A.png` and `val_B.png` inside `cfg.outputs/val`.
# - [ ] Reference these files in your README/report.

# %%
def run_validation(val_A: torch.Tensor, val_B: torch.Tensor):

    G_A2B.eval()
    G_B2A.eval()

    # A → B → A
    fake_B = G_A2B(val_A)
    rec_A  = G_B2A(fake_B)
    grid_A = torch.cat([val_A, fake_B, rec_A], dim=0)

    save_grid(
        epoch=None,   # 不用 epoch
        step=None,
        images=grid_A.cpu(),
        name="val_A",
        outputs_dir=Path(cfg.outputs) / "val"
    )

    # B → A → B
    fake_A = G_B2A(val_B)
    rec_B  = G_A2B(fake_A)
    grid_B = torch.cat([val_B, fake_A, rec_B], dim=0)

    save_grid(
        epoch=None,   # 不用 epoch
        step=None,
        images=grid_B.cpu(),
        name="val_B",
        outputs_dir=Path(cfg.outputs) / "val"
    )

    G_A2B.train()
    G_B2A.train()

    print("[Validation] Saved val_A.png and val_B.png")
run_validation(fixed_A, fixed_B)
img_A_path = Path(cfg.outputs) / "val" / "val_A_epoch_None.png"
img_B_path = Path(cfg.outputs) / "val" / "val_B_epoch_None.png"

# 讀取圖片
img_A = Image.open(img_A_path)
img_B = Image.open(img_B_path)

# 顯示圖片
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(img_A)
plt.title("Validation A → B → A")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(img_B)
plt.title("Validation B → A → B")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# --- [Log Success] Saved image grid to /home/vicky/ML-HW8/outputs/val/val_A_epoch_None.png
# --- [Log Success] Saved image grid to /home/vicky/ML-HW8/outputs/val/val_B_epoch_None.png
# [Validation] Saved val_A.png and val_B.png

# %% [markdown]
# ## 8. Test on Your Own Images
#
# Translate arbitrary photos (or sketches) using your trained models. This is where you demonstrate qualitative performance on data outside the original dataset.
#
# **Checklist**
# - [ ] Copy a few JPG/PNG files into a folder under `cfg.data_root` (e.g., `custom/`).
# - [ ] Reuse the deterministic test transforms before feeding them into the generators.
# - [ ] Visualize the outputs to `outputs/test` with direction-specific suffixes (e.g., `_A2B`, `_B2A`).
# - [ ] Discuss at least one success or one failure case in your report.

# %%
def translate_folder(input_dir: Path, model: nn.Module, output_dir: Path, tag: str):

    output_dir.mkdir(parents=True, exist_ok=True)

    transform = transforms.Compose([
        transforms.Resize((cfg.img_size, cfg.img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])

    model.eval()
    with torch.no_grad():
        for fname in os.listdir(input_dir):

            if not fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                continue

            img_path = input_dir / fname
            print(f"[Translate] Processing {img_path}")

            # 原圖讀取
            img = Image.open(img_path).convert("RGB")
            tensor = transform(img).unsqueeze(0).to(device)

            # 翻譯
            translated = model(tensor)[0]
            translated = translated.cpu() * 0.5 + 0.5
            translated_img = transforms.ToPILImage()(translated.clamp(0, 1))

            # 存檔
            out_path = output_dir / f"{fname.split('.')[0]}_{tag}.png"
            translated_img.save(out_path)
            print(f"[Translate] Saved to: {out_path}")

            # ==== 正確 plot：一張原圖 + 一張翻譯圖 ====
            plt.figure(figsize=(10, 4))

            plt.subplot(1, 2, 1)
            plt.imshow(img)
            plt.title("Original")
            plt.axis("off")

            plt.subplot(1, 2, 2)
            plt.imshow(translated_img)
            plt.title(f"Translated ({tag})")
            plt.axis("off")

            plt.tight_layout()
            plt.show()

    print(f"\n[Translate] All done. Outputs saved to: {output_dir.resolve()}")

custom_dir = Path(cfg.data_root) / "custom"
custom_dir.mkdir(parents=True, exist_ok=True)
print("\n--- Inference Setup ---")
print("Place your test images under:", custom_dir.resolve())

test_output_dir = Path(cfg.outputs) / "test"

translate_folder(custom_dir, G_B2A, test_output_dir, "B2A")
translate_folder(custom_dir, G_A2B, test_output_dir, "A2B")
# Out:
# --- Inference Setup ---
# Place your test images under: /home/vicky/ML-HW8/data/custom
# [Translate] Processing data/custom/90245.jpg
# [Translate] Saved to: outputs/test/90245_B2A.png
# [Translate] All done. Outputs saved to: /home/vicky/ML-HW8/outputs/test
# [Translate] Processing data/custom/90245.jpg
# [Translate] Saved to: outputs/test/90245_A2B.png
# [Translate] All done. Outputs saved to: /home/vicky/ML-HW8/outputs/test

# %% [markdown]
# ## 9. Expected Output & Turn-In Checklist
#
# Before you submit, make sure every item below is complete and easy to find inside your H.W.:
#
# - [ ] Plots or logs that show the trajectory of generator/discriminator losses (screenshots from TensorBoard are acceptable).
# - [ ] A report section explains any deviations, and summarizes lessons learned.
# - [ ] At least one custom-image translation result visualized with commentary in the report.

# %% [markdown]
# ## Your Report
